# %% [markdown]
# # Population Data Preparation - France pulation by communes
#
# **Project: Analysis of cultural accessibility and territorial inequalities in France**
#
# ### Research Questions:
# 1. Geographic Distribution: How is cultural supply distributed across French territories?
# 2. Urban vs Rural: Are there significant disparities between urban and rural areas?
# 3. Socio-Economic Correlation: Is there a relationship between territorial wealth and cultural supply?
# 4. Typological Diversity: What types of cultural venues exist and how are they distributed?
# 5. PACA Regional Focus: How does PACA compare to national averages?
# 6. How is public music infrastructure distributed across French departments?
#
# ---
#
# ## Dataset Information
#
# **Source:** INSEE (Institut National de la Statistique et des Études Économiques)
#
# **Name:** Populations légales - Population by commune
#
# **Origin:** Official French population census data
#
# **Year:** 2021 (most recent official data)
#
# **Last Update:** Published in 2023
#
# **Content:** Population counts for all French communes (~35,000 communes)
#
# **File Location:** `data/raw/demographics/ensemble.xlsx` (download from INSEE)
#
# **Alternative:** Can also be saved as CSV: `data/raw/demographics/population_communes.csv`
#
# **Download Link:** https://www.insee.fr/fr/statistiques/fichier/7739582/ensemble.xlsx
#
# **Purpose:** This dataset is for calculating cultural density (venues per 100k inhabitants)

# %% [markdown]
# ## Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Population Data
#
# **Options for loading:**
# 1. From Excel (original format)
# 2. From CSV (if you converted it)
#
# Choose ONE option below:

# %%
# Load from Excel 


df_population = pd.read_excel('../data/raw/ensemble.xlsx')

# OPTION 2: Load from CSV (if converted)
# df_population = pd.read_csv('data/raw/ensemble.csv', encoding='utf-8')

print(f" {len(df_population):,} rows")
print(f"Columns: {len(df_population.columns)}")
# Out:
#  24 rows
# Columns: 7
# C:\Users\mmouw\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ## Explore the Data

# %%
df_population.head()
# Out:
#   Populations légales des régions en vigueur au 1er janvier 2024  \
# 0                        Mise à jour : décembre 2023
# 1                                        en habitant
# 2  Champ : France métropolitaine, départements d’...
# 3   Date de référence statistique : 1er janvier 2021
# 4                                           Source :
#
#                                  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                       NaN        NaN        NaN        NaN
# 1                                       NaN        NaN        NaN        NaN
# 2                                       NaN        NaN        NaN        NaN
# 3                                       NaN        NaN        NaN        NaN
# 4  Insee, Recensement de la population 2021        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Column names
for i, col in enumerate(df_population.columns, 1):
    print(f"{i:2d}. {col}")
# Out:
#  1. Populations légales des régions en vigueur au 1er janvier 2024
#  2. Unnamed: 1
#  3. Unnamed: 2
#  4. Unnamed: 3
#  5. Unnamed: 4
#  6. Unnamed: 5
#  7. Unnamed: 6

# %%
# Dataset info
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Populations légales des régions en vigueur au 1er janvier 2024  23 non-null     object
#  1   Unnamed: 1                                                      19 non-null     object
#  2   Unnamed: 2                                                      18 non-null     object
#  3   Unnamed: 3                                                      16 non-null     object
#  4   Unnamed: 4                                                      18 non-null     object
#  5   Unnamed: 5                                                      18 non-null     object
#  6   Unnamed: 6                                                      18 non-null     object
# dtypes: object(7)
# memory usage: 1.4+ KB

# %%
import openpyxl

preview = pd.read_excel("../data/raw/ensemble.xlsx", header=None, nrows=20)
preview

# column names : row 7 !
# Out:
# C:\Users\mmouw\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                     0  \
# 0   Populations légales des régions en vigueur au ...
# 1                         Mise à jour : décembre 2023
# 2                                         en habitant
# 3   Champ : France métropolitaine, départements d’...
# 4    Date de référence statistique : 1er janvier 2021
# 5                                            Source :
# 6                                                 NaN
# 7                                         Code région
# 8                                                  84
# 9                                                  27
# 10                                                 53
# 11                                                 24
# 12                                                 94
# 13                                                 44
# 14                                                 01
# 15                                                 03
# 16                                                 32
# 17                                                 04
# 18                                                 02
# 19                                                 28
#
#                                            1                         2  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
# 3                                        NaN                       NaN
# 4                                        NaN                       NaN
# 5   Insee, Recensement de la population 2021                       NaN
# 6                                        NaN                       NaN
# 7                           Nom de la région  Nombre d'arrondissements
# 8                       Auvergne-Rhône-Alpes                        39
# 9                    Bourgogne-Franche-Comté                        24
# 10                                  Bretagne                        15
# 11                       Centre-Val de Loire                        20
# 12                                     Corse                         5
# 13                                 Grand Est                        38
# 14                                Guadeloupe                         2
# 15                                    Guyane                         3
# 16                           Hauts-de-France                        26
# 17                                La Réunion                         4
# 18                                Martinique                         4
# 19                                 Normandie                        17
#
#                     3                   4                      5  \
# 0                 NaN                 NaN                    NaN
# 1                 NaN                 NaN                    NaN
# 2                 NaN                 NaN                    NaN
# 3                 NaN                 NaN                    NaN
# 4                 NaN                 NaN                    NaN
# 5                 NaN                 NaN                    NaN
# 6                 NaN                 NaN                    NaN
# 7   Nombre de cantons  Nombre de communes  Population municipale
# 8                 241                4028                8114361
# 9                 152                3699                2800194
# 10                102                1207                3394567
# 11                102                1757                2573303
# 12                 26                 360                 347597
# 13                200                5119                5561287
# 14                 21                  32                 384315
# 15                NaN                  22                 286618
# 16                145                3787                5995292
# 17                 25                  24                 871157
# 18                NaN                  34                 360749
# 19                131                2651                3327966
#
#                     6
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7   Population totale
# 8             8284162
# 9             2872386
# 10            3482543
# 11            2630743
# 12             352559
# 13            5665457
# 14             389277
# 15             288739
# 16            6085665
# 17             880875
# 18             364916
# 19            3398102

# %%
df_population = pd.read_excel(
    "../data/raw/ensemble.xlsx",
    skiprows=7,
    header=0
)

df_population.head(2)
# Out:
# C:\Users\mmouw\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Code région         Nom de la région  Nombre d'arrondissements  \
# 0           84     Auvergne-Rhône-Alpes                        39
# 1           27  Bourgogne-Franche-Comté                        24
#
#    Nombre de cantons  Nombre de communes  Population municipale  \
# 0              241.0                4028                8114361
# 1              152.0                3699                2800194
#
#    Population totale
# 0            8284162
# 1            2872386

# %%
# Statistical summary
df_population.describe()
# Out:
#        Code région  Nombre d'arrondissements  Nombre de cantons  \
# count    17.000000                 17.000000          15.000000
# mean     41.352941                 19.588235         136.000000
# std      33.151058                 13.370017          77.642036
# min       1.000000                  2.000000          21.000000
# 25%      11.000000                  5.000000         102.000000
# 50%      32.000000                 18.000000         131.000000
# 75%      75.000000                 26.000000         177.500000
# max      94.000000                 41.000000         258.000000
#
#        Nombre de communes  Population municipale  Population totale
# count           17.000000           1.700000e+01       1.700000e+01
# mean          2054.588235           3.965180e+06       4.036504e+06
# std           1816.691672           3.256699e+06       3.299959e+06
# min             22.000000           2.866180e+05       2.887390e+05
# 25%            360.000000           8.711570e+05       8.808750e+05
# 50%           1268.000000           3.394567e+06       3.482543e+06
# 75%           3787.000000           5.995292e+06       6.085665e+06
# max           5119.000000           1.231728e+07       1.242798e+07

# %% [markdown]
# ## Clean the data

# %%
print(df_population.columns.tolist())
# Out:
# ['Code région', 'Nom de la région', "Nombre d'arrondissements", 'Nombre de cantons', 'Nombre de communes', 'Population municipale', 'Population totale']

# %%
# Select only necessary columns 
columns_to_keep = [
    "Code région",
    "Nom de la région",
    "Nombre d'arrondissements",
    "Nombre de cantons",
    "Nombre de communes",
    "Population municipale",
    "Population totale"
]

columns_to_keep = [c for c in columns_to_keep if c in df_population.columns]
df_pop_clean = df_population[columns_to_keep].copy()

# Rename columns (SQL)
df_pop_clean = df_pop_clean.rename(columns={
    "Code région": "region_code",
    "Nom de la région": "region_name",
    "Nombre d'arrondissements": "nb_arrondissements",
    "Nombre de cantons": "nb_cantons",
    "Nombre de communes": "nb_communes",
    "Population municipale": "population_municipale",
    "Population totale": "population_totale",
})

print(f"{len(df_pop_clean.columns)} columns")
print(f"Rows: {len(df_pop_clean):,}")
df_pop_clean.head()
# Out:
# 7 columns
# Rows: 17
#    region_code              region_name  nb_arrondissements  nb_cantons  \
# 0           84     Auvergne-Rhône-Alpes                  39       241.0
# 1           27  Bourgogne-Franche-Comté                  24       152.0
# 2           53                 Bretagne                  15       102.0
# 3           24      Centre-Val de Loire                  20       102.0
# 4           94                    Corse                   5        26.0
#
#    nb_communes  population_municipale  population_totale
# 0         4028                8114361            8284162
# 1         3699                2800194            2872386
# 2         1207                3394567            3482543
# 3         1757                2573303            2630743
# 4          360                 347597             352559

# %%
# Preparation for SQL 


# Clean population columns (convert to int)

df_pop_clean["population_municipale"] = (
    pd.to_numeric(df_pop_clean["population_municipale"], errors="coerce")
    .fillna(0)
    .astype(int))

df_pop_clean["population_totale"] = (
    pd.to_numeric(df_pop_clean["population_totale"], errors="coerce")
    .fillna(0)
    .astype(int))

df_pop_clean.head()

# %%
# Check for missing values
print("Missing values:")
print(df_pop_clean.isnull().sum())

# %% [markdown]
# ## CSV file

# %%
import os
os.makedirs('data/processed', exist_ok=True)

output_file = 'data/processed/population_for_sql.csv'
df_pop_clean.to_csv(output_file, index=False, encoding='utf-8')

print(f" Data saved to: {output_file}")
print(f"   Rows: {len(df_pop_clean):,}")
print(f"   Columns: {len(df_pop_clean.columns)}")
